# %%
import sqlalchemy
import pandas as pd
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from config import password
import json
import plotly.express as px
from scipy.stats import linregress
import plotly.graph_objects as go

# %%
username = "wnpdgutwqozkwm" 
Base = automap_base()

engine = create_engine(f'postgres://{username}:{password}@ec2-3-211-37-117.compute-1.amazonaws.com:5432/d4rg5ld0gedobs')

# %%
# engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/Project-2')

# Base.prepare(engine, reflect=True)

# %%
# def pull2021Data(year):
world_data = pd.read_sql(f"SELECT * FROM happiness_data WHERE year = 2021;", con=engine)
world_data_json = world_data.to_json(orient="records")
print(world_data_json)
# Out:
# [{"country":"Finland","happiness_rank":1,"happiness_score":7.842,"economy_gdp_per_capita":10.775,"health_life_expectancy":0.826057946,"freedom":0.949,"trust_government_corruption":0.186,"generosity":-0.098,"year":2021},{"country":"Denmark","happiness_rank":2,"happiness_score":7.62,"economy_gdp_per_capita":10.933,"health_life_expectancy":0.850640913,"freedom":0.946,"trust_government_corruption":0.179,"generosity":0.03,"year":2021},{"country":"Switzerland","happiness_rank":3,"happiness_score":7.571,"economy_gdp_per_capita":11.117,"health_life_expectancy":0.910342406,"freedom":0.919,"trust_government_corruption":0.292,"generosity":0.025,"year":2021},{"country":"Iceland","happiness_rank":4,"happiness_score":7.554,"economy_gdp_per_capita":10.878,"health_life_expectancy":0.861176471,"freedom":0.955,"trust_government_corruption":0.673,"generosity":0.16,"year":2021},{"country":"Netherlands","happiness_rank":5,"happiness_score":7.464,"economy_gdp_per_capita":10.932,"health_life_expectancy":0.840105356,"freedom":0.913,"trust_government_corruption":0.338,"generosity":0.175,"year":2021},{"country":"Norway","happiness_rank":6,"happiness_score":7.392,"economy_gdp_per_capita":11.053,"health_life_expectancy":0.871712028,"freedom":0.96,"trust_government_corruption":0.27,"generosity":0.093,"year":2021},{"country":"Sweden","happiness_rank":7,"happiness_score":7.363,"economy_gdp_per_capita":10.867,"health_life_expectancy":0.850640913,"freedom":0.945,"trust_government_corruption":0.237,"generosity":0.086,"year":2021},{"country":"Luxembourg","happiness_rank":8,"happiness_score":7.324,"economy_gdp_per_capita":11.647,"health_life_expectancy":0.847129061,"freedom":0.907,"trust_government_corruption":0.386,"generosity":-0.034,"year":2021},{"country":"New Zealand","happiness_rank":9,"happiness_score":7.277,"economy_gdp_per_capita":10.643,"health_life_expectancy":0.875223881,"freedom":0.929,"trust_government_corruption":0.242,"generosity":0.134,"year":2021},{"country":"Austria","happiness_rank":10,"happiness_score":7.268,"economy_gdp_per_capita":10.906,"health_life_expectancy":0.871712028,"freedom":0.908,"trust_government_corruption":0.481,"generosity":0.042,"year":2021},{"country":"Australia","happiness_rank":11,"happiness_score":7.183,"economy_gdp_per_capita":10.796,"health_life_expectancy":0.892783143,"freedom":0.914,"trust_government_corruption":0.442,"generosity":0.159,"year":2021},{"country":"Israel","happiness_rank":12,"happiness_score":7.157,"economy_gdp_per_capita":10.575,"health_life_expectancy":0.878841089,"freedom":0.8,"trust_government_corruption":0.753,"generosity":0.031,"year":2021},{"country":"Germany","happiness_rank":13,"happiness_score":7.155,"economy_gdp_per_capita":10.873,"health_life_expectancy":0.843617208,"freedom":0.875,"trust_government_corruption":0.46,"generosity":0.011,"year":2021},{"country":"Canada","happiness_rank":14,"happiness_score":7.103,"economy_gdp_per_capita":10.776,"health_life_expectancy":0.889271291,"freedom":0.915,"trust_government_corruption":0.415,"generosity":0.089,"year":2021},{"country":"Ireland","happiness_rank":15,"happiness_score":7.085,"economy_gdp_per_capita":11.342,"health_life_expectancy":0.840105356,"freedom":0.879,"trust_government_corruption":0.363,"generosity":0.077,"year":2021},{"country":"Costa Rica","happiness_rank":16,"happiness_score":7.069,"economy_gdp_per_capita":9.88,"health_life_expectancy":0.804986831,"freedom":0.934,"trust_government_corruption":0.809,"generosity":-0.126,"year":2021},{"country":"United Kingdom","happiness_rank":17,"happiness_score":7.064,"economy_gdp_per_capita":10.707,"health_life_expectancy":0.843617208,"freedom":0.859,"trust_government_corruption":0.459,"generosity":0.233,"year":2021},{"country":"Czech Republic","happiness_rank":18,"happiness_score":6.965,"economy_gdp_per_capita":10.556,"health_life_expectancy":0.784161545,"freedom":0.858,"trust_government_corruption":0.868,"generosity":-0.208,"year":2021},{"country":"United States","happiness_rank":19,"happiness_sc ...

# %%
json.loads(world_data_json)
# Out:
# [{'country': 'Finland',
#   'happiness_rank': 1,
#   'happiness_score': 7.842,
#   'economy_gdp_per_capita': 10.775,
#   'health_life_expectancy': 0.826057946,
#   'freedom': 0.949,
#   'trust_government_corruption': 0.186,
#   'generosity': -0.098,
#   'year': 2021},
#  {'country': 'Denmark',
#   'happiness_rank': 2,
#   'happiness_score': 7.62,
#   'economy_gdp_per_capita': 10.933,
#   'health_life_expectancy': 0.850640913,
#   'freedom': 0.946,
#   'trust_government_corruption': 0.179,
#   'generosity': 0.03,
#   'year': 2021},
#  {'country': 'Switzerland',
#   'happiness_rank': 3,
#   'happiness_score': 7.571,
#   'economy_gdp_per_capita': 11.117,
#   'health_life_expectancy': 0.910342406,
#   'freedom': 0.919,
#   'trust_government_corruption': 0.292,
#   'generosity': 0.025,
#   'year': 2021},
#  {'country': 'Iceland',
#   'happiness_rank': 4,
#   'happiness_score': 7.554,
#   'economy_gdp_per_capita': 10.878,
#   'health_life_expectancy': 0.861176471,
#   'freedom': 0.955,
#   'trust_government_corruption': 0.673,
#   'generosity': 0.16,
#   'year': 2021},
#  {'country': 'Netherlands',
#   'happiness_rank': 5,
#   'happiness_score': 7.464,
#   'economy_gdp_per_capita': 10.932,
#   'health_life_expectancy': 0.840105356,
#   'freedom': 0.913,
#   'trust_government_corruption': 0.338,
#   'generosity': 0.175,
#   'year': 2021},
#  {'country': 'Norway',
#   'happiness_rank': 6,
#   'happiness_score': 7.392,
#   'economy_gdp_per_capita': 11.053,
#   'health_life_expectancy': 0.871712028,
#   'freedom': 0.96,
#   'trust_government_corruption': 0.27,
#   'generosity': 0.093,
#   'year': 2021},
#  {'country': 'Sweden',
#   'happiness_rank': 7,
#   'happiness_score': 7.363,
#   'economy_gdp_per_capita': 10.867,
#   'health_life_expectancy': 0.850640913,
#   'freedom': 0.945,
#   'trust_government_corruption': 0.237,
#   'generosity': 0.086,
#   'year': 2021},
#  {'country': 'Luxembourg',
#   'happiness_rank': 8,
#   'happiness_score': 7.324,
#   'economy_gdp_per_capita': 11.647,
#   'health_life_expectancy': 0.847129061,
#   'freedom': 0.907,
#   'trust_government_corruption': 0.386,
#   'generosity': -0.034,
#   'year': 2021},
#  {'country': 'New Zealand',
#   'happiness_rank': 9,
#   'happiness_score': 7.277,
#   'economy_gdp_per_capita': 10.643,
#   'health_life_expectancy': 0.875223881,
#   'freedom': 0.929,
#   'trust_government_corruption': 0.242,
#   'generosity': 0.134,
#   'year': 2021},
#  {'country': 'Austria',
#   'happiness_rank': 10,
#   'happiness_score': 7.268,
#   'economy_gdp_per_capita': 10.906,
#   'health_life_expectancy': 0.871712028,
#   'freedom': 0.908,
#   'trust_government_corruption': 0.481,
#   'generosity': 0.042,
#   'year': 2021},
#  {'country': 'Australia',
#   'happiness_rank': 11,
#   'happiness_score': 7.183,
#   'economy_gdp_per_capita': 10.796,
#   'health_life_expectancy': 0.892783143,
#   'freedom': 0.914,
#   'trust_government_corruption': 0.442,
#   'generosity': 0.159,
#   'year': 2021},
#  {'country': 'Israel',
#   'happiness_rank': 12,
#   'happiness_score': 7.157,
#   'economy_gdp_per_capita': 10.575,
#   'health_life_expectancy': 0.878841089,
#   'freedom': 0.8,
#   'trust_government_corruption': 0.753,
#   'generosity': 0.031,
#   'year': 2021},
#  {'country': 'Germany',
#   'happiness_rank': 13,
#   'happiness_score': 7.155,
#   'economy_gdp_per_capita': 10.873,
#   'health_life_expectancy': 0.843617208,
#   'freedom': 0.875,
#   'trust_government_corruption': 0.46,
#   'generosity': 0.011,
#   'year': 2021},
#  {'country': 'Canada',
#   'happiness_rank': 14,
#   'happiness_score': 7.103,
#   'economy_gdp_per_capita': 10.776,
#   'health_life_expectancy': 0.889271291,
#   'freedom': 0.915,
#   'trust_government_corruption': 0.415,
#   'generosity': 0.089,
#   'year': 2021},
#  {'country': 'Ireland',
#   'happiness_rank': 15,
#   'happiness_score': 7.085,
#   'economy_gdp_per_capita': 11.342,
#   'health_life_expectancy': 0.840105356,
#   'freedom': 0.879,
#   'trust_government_corruption': 0.363,
#   'generosity': 0.077,
#   'year': 2021},
#  {'country': 'Costa Rica',
#   'happiness_rank': 16,
#   'happiness_score': 7.069,
#   'economy_gdp_per_capita': 9.88,
#   'health_life_expectancy': 0.804986831,
#   'freedom': 0.934,
#   'trust_government_corruption': 0.809,
#   'generosity': -0.126,
#   'year': 2021},
#  {'country': 'United Kingdom',
#   'happiness_rank': 17,
#   'happiness_score': 7.064,
#   'economy_gdp_per_capita': 10.707,
#   'health_life_expectancy': 0.843617208,
#   'freedom': 0.859,
#   'trust_government_corruption': 0.459,
#   'generosity': 0.233,
#   'year': 2021},
#  {'country': 'Czech Republic',
#   'happiness_rank': 18,
#   'happiness_score': 6.965,
#   'economy_gdp_per_capita': 10.556,
#   'health_life_expectancy': 0.784161545,
#   'freedom': 0.858,
#   'trust_government_corruption': 0.868,
#   'generosity': -0.208,
#   'year': 2021},
#  {'country': 'United States',
#   'happiness_rank': 19,
#   'happiness_score': 6.951,
#   'economy_gdp_per_capita': 11.023,
#   'health_life_expectancy': 0.69260755,
#   'freedom': 0.837,
#   'trust_government_corruption': 0.698,
#   'generosity': 0.098,
#   'year': 2021},
#  {'country': 'Belgium',
#   'happiness_rank': 20,
#   'happiness_score': 6.834,
#   'economy_gdp_per_capita': 10.823,
#   'health_life_expectancy': 0.833046532,
#   'freedom': 0.783,
#   'trust_government_corruption': 0.646,
#   'generosity': -0.153,
#   'year': 2021},
#  {'country': 'France',
#   'happiness_rank': 21,
#   'happiness_score': 6.69,
#   'economy_gdp_per_capita': 10.704,
#   'health_life_expectancy': 0.896294996,
#   'freedom': 0.822,
#   'trust_government_corruption': 0.571,
#   'generosity': -0.147,
#   'year': 2021},
#  {'country': 'Bahrain',
#   'happiness_rank': 22,
#   'happiness_score': 6.647,
#   'economy_gdp_per_capita': 10.669,
#   'health_life_expectancy': 0.73808604,
#   'freedom': 0.925,
#   'trust_government_corruption': 0.722,
#   'generosity': 0.089,
#   'year': 2021},
#  {'country': 'Malta',
#   'happiness_rank': 23,
#   'happiness_score': 6.602,
#   'economy_gdp_per_capita': 10.674,
#   'health_life_expectancy': 0.833081651,
#   'freedom': 0.927,
#   'trust_government_corruption': 0.653,
#   'generosity': 0.133,
#   'year': 2021},
#  {'country': 'United Arab Emirates',
#   'happiness_rank': 25,
#   'happiness_score': 6.561,
#   'economy_gdp_per_capita': 11.085,
#   'health_life_expectancy': 0.662159789,
#   'freedom': 0.932,
#   'trust_government_corruption': 0.589,
#   'generosity': 0.074,
#   'year': 2021},
#  {'country': 'Saudi Arabia',
#   'happiness_rank': 26,
#   'happiness_score': 6.494,
#   'economy_gdp_per_capita': 10.743,
#   'health_life_expectancy': 0.636523266,
#   'freedom': 0.877,
#   'trust_government_corruption': 0.684,
#   'generosity': -0.149,
#   'year': 2021},
#  {'country': 'Spain',
#   'happiness_rank': 27,
#   'happiness_score': 6.491,
#   'economy_gdp_per_capita': 10.571,
#   'health_life_expectancy': 0.920877963,
#   'freedom': 0.761,
#   'trust_government_corruption': 0.745,
#   'generosity': -0.081,
#   'year': 2021},
#  {'country': 'Italy',
#   'happiness_rank': 28,
#   'happiness_score': 6.483,
#   'economy_gdp_per_capita': 10.623,
#   'health_life_expectancy': 0.889271291,
#   'freedom': 0.693,
#   'trust_government_corruption': 0.866,
#   'generosity': -0.084,
#   'year': 2021},
#  {'country': 'Slovenia',
#   'happiness_rank': 29,
#   'happiness_score': 6.461,
#   'economy_gdp_per_capita': 10.529,
#   'health_life_expectancy': 0.804986831,
#   'freedom': 0.949,
#   'trust_government_corruption': 0.806,
#   'generosity': -0.101,
#   'year': 2021},
#  {'country': 'Guatemala',
#   'happiness_rank': 30,
#   'happiness_score': 6.435,
#   'economy_gdp_per_capita': 9.053,
#   'health_life_expectancy': 0.578753292,
#   'freedom': 0.906,
#   'trust_government_corruption': 0.775,
#   'generosity': -0.038,
#   'year': 2021},
#  {'country': 'Uruguay',
#   'happiness_rank': 31,
#   'happiness_score': 6.431,
#   'economy_gdp_per_capita': 9.966,
#   'health_life_expectancy': 0.724214223,
#   'freedom': 0.896,
#   'trust_government_corruption': 0.59,
#   'generosity': -0.092,
#   'year': 2021},
#  {'country': 'Singapore',
#   'happiness_rank': 32,
#   'happiness_score': 6.377,
#   'economy_gdp_per_capita': 11.488,
#   'health_life_expectancy': 1.0,
#   'freedom': 0.927,
#   'trust_government_corruption': 0.082,
#   'generosity': -0.018,
#   'year': 2021},
#  {'country': 'Slovakia',
#   'happiness_rank': 34,
#   'happiness_score': 6.331,
#   'economy_gdp_per_capita': 10.369,
#   'health_life_expectancy': 0.727761194,
#   'freedom': 0.766,
#   'trust_government_corruption': 0.911,
#   'generosity': -0.124,
#   'year': 2021},
#  {'country': 'Brazil',
#   'happiness_rank': 35,
#   'happiness_score': 6.33,
#   'economy_gdp_per_capita': 9.577,
#   'health_life_expectancy': 0.636453029,
#   'freedom': 0.804,
#   'trust_government_corruption': 0.756,
#   'generosity': -0.071,
#   'year': 2021},
#  {'country': 'Mexico',
#   'happiness_rank': 36,
#   'happiness_score': 6.317,
#   'economy_gdp_per_capita': 9.859,
#   'health_life_expectancy': 0.706549605,
#   'freedom': 0.862,
#   'trust_government_corruption': 0.799,
#   'generosity': -0.147,
#   'year': 2021},
#  {'country': 'Jamaica',
#   'happiness_rank': 37,
#   'happiness_score': 6.309,
#   'economy_gdp_per_capita': 9.186,
#   'health_life_expectancy': 0.668024583,
#   'freedom': 0.89,
#   'trust_government_corruption': 0.884,
#   'generosity': -0.137,
#   'year': 2021},
#  {'country': 'Lithuania',
#   'happiness_rank': 38,
#   'happiness_score': 6.255,
#   'economy_gdp_per_capita': 10.499,
#   'health_life_expectancy': 0.682282704,
#   'freedom': 0.773,
#   'trust_government_corruption': 0.826,
#   'generosity': -0.203,
#   'year': 2021},
#  {'country': 'Cyprus',
#   'happiness_rank': 39,
#   'happiness_score': 6.223,
#   'economy_gdp_per_capita': 10.576,
#   'health_life_expectancy': 0.892712906,
#   'freedom': 0.763,
#   'trust_government_corruption': 0.844,
#   'generosity': -0.015,
#   'year': 2021},
#  {'country': 'Estonia',
#   'happiness_rank': 40,
#   'happiness_score': 6.189,
#   'economy_gdp_per_capita': 10.481,
#   'health_life_expectancy': 0.713678665,
#   'freedom': 0.909,
#   'trust_government_corruption': 0.527,
#   'generosity': -0.106,
#   'year': 2021},
#  {'country': 'Panama',
#   'happiness_rank': 41,
#   'happiness_score': 6.18,
#   'economy_gdp_per_capita': 10.35,
#   'health_life_expectancy': 0.743599649,
#   'freedom': 0.872,
#   'trust_government_corruption': 0.856,
#   'generosity': -0.166,
#   'year': 2021},
#  {'country': 'Uzbekistan',
#   'happiness_rank': 42,
#   'happiness_score': 6.179,
#   'economy_gdp_per_capita': 8.836,
#   'health_life_expectancy': 0.589183494,
#   'freedom': 0.97,
#   'trust_government_corruption': 0.515,
#   'generosity': 0.311,
#   'year': 2021},
#  {'country': 'Chile',
#   'happiness_rank': 43,
#   'happiness_score': 6.172,
#   'economy_gdp_per_capita': 10.071,
#   'health_life_expectancy': 0.755820896,
#   'freedom': 0.742,
#   'trust_government_corruption': 0.83,
#   'generosity': -0.044,
#   'year': 2021},
#  {'country': 'Poland',
#   'happiness_rank': 44,
#   'happiness_score': 6.166,
#   'economy_gdp_per_capita': 10.382,
#   'health_life_expectancy': 0.745355575,
#   'freedom': 0.841,
#   'trust_government_corruption': 0.735,
#   'generosity': -0.165,
#   'year': 2021},
#  {'country': 'Kazakhstan',
#   'happiness_rank': 45,
#   'happiness_score': 6.152,
#   'economy_gdp_per_capita': 10.155,
#   'health_life_expectancy': 0.587251975,
#   'freedom': 0.853,
#   'trust_government_corruption': 0.733,
#   'generosity': -0.069,
#   'year': 2021},
#  {'country': 'Romania',
#   'happiness_rank': 46,
#   'happiness_score': 6.14,
#   'economy_gdp_per_capita': 10.284,
#   'health_life_expectancy': 0.662932397,
#   'freedom': 0.845,
#   'trust_government_corruption': 0.938,
#   'generosity': -0.219,
#   'year': 2021},
#  {'country': 'Kuwait',
#   'happiness_rank': 47,
#   'happiness_score': 6.106,
#   'economy_gdp_per_capita': 10.817,
#   'health_life_expectancy': 0.646953468,
#   'freedom': 0.867,
#   'trust_government_corruption': 0.736,
#   'generosity': -0.104,
#   'year': 2021},
#  {'country': 'Serbia',
#   'happiness_rank': 48,
#   'happiness_score': 6.078,
#   'economy_gdp_per_capita': 9.787,
#   'health_life_expectancy': 0.70665496,
#   'freedom': 0.778,
#   'trust_government_corruption': 0.835,
#   'generosity': 0.002,
#   'year': 2021},
#  {'country': 'El Salvador',
#   'happiness_rank': 49,
#   'happiness_score': 6.061,
#   'economy_gdp_per_capita': 9.054,
#   'health_life_expectancy': 0.629464442,
#   'freedom': 0.888,
#   'trust_government_corruption': 0.688,
#   'generosity': -0.11,
#   'year': 2021},
#  {'country': 'Mauritius',
#   'happiness_rank': 50,
#   'happiness_score': 6.049,
#   'economy_gdp_per_capita': 10.008,
#   'health_life_expectancy': 0.639964881,
#   'freedom': 0.867,
#   'trust_government_corruption': 0.789,
#   'generosity': -0.054,
#   'year': 2021},
#  {'country': 'Latvia',
#   'happiness_rank': 51,
#   'happiness_score': 6.032,
#   'economy_gdp_per_capita': 10.315,
#   'health_life_expectancy': 0.653977173,
#   'freedom': 0.715,
#   'trust_government_corruption': 0.8,
#   'generosity': -0.162,
#   'year': 2021},
#  {'country': 'Colombia',
#   'happiness_rank': 52,
#   'happiness_score': 6.012,
#   'economy_gdp_per_capita': 9.557,
#   'health_life_expectancy': 0.685618964,
#   'freedom': 0.837,
#   'trust_government_corruption': 0.841,
#   'generosity': -0.135,
#   'year': 2021},
#  {'country': 'Hungary',
#   'happiness_rank': 53,
#   'happiness_score': 5.992,
#   'economy_gdp_per_capita': 10.358,
#   'health_life_expectancy': 0.685583845,
#   'freedom': 0.755,
#   'trust_government_corruption': 0.876,
#   'generosity': -0.186,
#   'year': 2021},
#  {'country': 'Thailand',
#   'happiness_rank': 54,
#   'happiness_score': 5.985,
#   'economy_gdp_per_capita': 9.805,
#   'health_life_expectancy': 0.664547849,
#   'freedom': 0.884,
#   'trust_government_corruption': 0.895,
#   'generosity': 0.287,
#   'year': 2021},
#  {'country': 'Nicaragua',
#   'happiness_rank': 55,
#   'happiness_score': 5.972,
#   'economy_gdp_per_capita': 8.62,
#   'health_life_expectancy': 0.673538191,
#   'freedom': 0.836,
#   'trust_government_corruption': 0.664,
#   'generosity': 0.02,
#   'year': 2021},
#  {'country': 'Japan',
#   'happiness_rank': 56,
#   'happiness_score': 5.94,
#   'economy_gdp_per_capita': 10.611,
#   'health_life_expectancy': 0.934925373,
#   'freedom': 0.796,
#   'trust_government_corruption': 0.638,
#   'generosity': -0.258,
#   'year': 2021},
#  {'country': 'Argentina',
#   'happiness_rank': 57,
#   'happiness_score': 5.929,
#   'economy_gdp_per_capita': 9.962,
#   'health_life_expectancy': 0.720702371,
#   'freedom': 0.828,
#   'trust_government_corruption': 0.834,
#   'generosity': -0.182,
#   'year': 2021},
#  {'country': 'Portugal',
#   'happiness_rank': 58,
#   'happiness_score': 5.929,
#   'economy_gdp_per_capita': 10.421,
#   'health_life_expectancy': 0.847129061,
#   'freedom': 0.892,
#   'trust_government_corruption': 0.887,
#   'generosity': -0.244,
#   'year': 2021},
#  {'country': 'Honduras',
#   'happiness_rank': 59,
#   'happiness_score': 5.919,
#   'economy_gdp_per_capita': 8.648,
#   'health_life_expectancy': 0.661000878,
#   'freedom': 0.857,
#   'trust_government_corruption': 0.809,
#   'generosity': 0.081,
#   'year': 2021},
#  {'country': 'Croatia',
#   'happiness_rank': 60,
#   'happiness_score': 5.882,
#   'economy_gdp_per_capita': 10.217,
#   'health_life_expectancy': 0.783880597,
#   'freedom': 0.754,
#   'trust_government_corruption': 0.939,
#   'generosity': -0.118,
#   'year': 2021},
#  {'country': 'Philippines',
#   'happiness_rank': 61,
#   'happiness_score': 5.88,
#   'economy_gdp_per_capita': 9.076,
#   'health_life_expectancy': 0.474872695,
#   'freedom': 0.917,
#   'trust_government_corruption': 0.742,
#   'generosity': -0.097,
#   'year': 2021},
#  {'country': 'South Korea',
#   'happiness_rank': 62,
#   'happiness_score': 5.845,
#   'economy_gdp_per_capita': 10.651,
#   'health_life_expectancy': 0.892783143,
#   'freedom': 0.672,
#   'trust_government_corruption': 0.727,
#   'generosity': -0.083,
#   'year': 2021},
#  {'country': 'Peru',
#   'happiness_rank': 63,
#   'happiness_score': 5.84,
#   'economy_gdp_per_capita': 9.458,
#   'health_life_expectancy': 0.694363477,
#   'freedom': 0.822,
#   'trust_government_corruption': 0.891,
#   'generosity': -0.154,
#   'year': 2021},
#  {'country': 'Bosnia and Herzegovina',
#   'happiness_rank': 64,
#   'happiness_score': 5.813,
#   'economy_gdp_per_capita': 9.59,
#   'health_life_expectancy': 0.689025461,
#   'freedom': 0.706,
#   'trust_government_corruption': 0.931,
#   'generosity': 0.113,
#   'year': 2021},
#  {'country': 'Moldova',
#   'happiness_rank': 65,
#   'happiness_score': 5.766,
#   'economy_gdp_per_capita': 9.454,
#   'health_life_expectancy': 0.604776119,
#   'freedom': 0.822,
#   'trust_government_corruption': 0.918,
#   'generosity': -0.079,
#   'year': 2021},
#  {'country': 'Ecuador',
#   'happiness_rank': 66,
#   'happiness_score': 5.764,
#   'economy_gdp_per_capita': 9.313,
#   'health_life_expectancy': 0.713678665,
#   'freedom': 0.842,
#   'trust_government_corruption': 0.843,
#   'generosity': -0.124,
#   'year': 2021},
#  {'country': 'Kyrgyzstan',
#   'happiness_rank': 67,
#   'happiness_score': 5.744,
#   'economy_gdp_per_capita': 8.538,
#   'health_life_expectancy': 0.559192274,
#   'freedom': 0.935,
#   'trust_government_corruption': 0.908,
#   'generosity': 0.119,
#   'year': 2021},
#  {'country': 'Greece',
#   'happiness_rank': 68,
#   'happiness_score': 5.723,
#   'economy_gdp_per_capita': 10.279,
#   'health_life_expectancy': 0.847129061,
#   'freedom': 0.582,
#   'trust_government_corruption': 0.823,
#   'generosity': -0.288,
#   'year': 2021},
#  {'country': 'Bolivia',
#   'happiness_rank': 69,
#   'happiness_score': 5.716,
#   'economy_gdp_per_capita': 9.046,
#   'health_life_expectancy': 0.541633011,
#   'freedom': 0.875,
#   'trust_government_corruption': 0.839,
#   'generosity': -0.077,
#   'year': 2021},
#  {'country': 'Mongolia',
#   'happiness_rank': 70,
#   'happiness_score': 5.677,
#   'economy_gdp_per_capita': 9.4,
#   'health_life_expectancy': 0.492431958,
#   'freedom': 0.708,
#   'trust_government_corruption': 0.856,
#   'generosity': 0.116,
#   'year': 2021},
#  {'country': 'Paraguay',
#   'happiness_rank': 71,
#   'happiness_score': 5.653,
#   'economy_gdp_per_capita': 9.448,
#   'health_life_expectancy': 0.611834943,
#   'freedom': 0.876,
#   'trust_government_corruption': 0.882,
#   'generosity': 0.028,
#   'year': 2021},
#  {'country': 'Montenegro',
#   'happiness_rank': 72,
#   'happiness_score': 5.581,
#   'economy_gdp_per_capita': 9.94,
#   'health_life_expectancy': 0.710131694,
#   'freedom': 0.708,
#   'trust_government_corruption': 0.812,
#   'generosity': -0.034,
#   'year': 2021},
#  {'country': 'Dominican Republic',
#   'happiness_rank': 73,
#   'happiness_score': 5.545,
#   'economy_gdp_per_capita': 9.802,
#   'health_life_expectancy': 0.618928885,
#   'freedom': 0.86,
#   'trust_government_corruption': 0.714,
#   'generosity': -0.133,
#   'year': 2021},
#  {'country': 'Belarus',
#   'happiness_rank': 75,
#   'happiness_score': 5.534,
#   'economy_gdp_per_capita': 9.853,
#   'health_life_expectancy': 0.624231782,
#   'freedom': 0.65,
#   'trust_government_corruption': 0.627,
#   'generosity': -0.18,
#   'year': 2021},
#  {'country': 'Russia',
#   'happiness_rank': 76,
#   'happiness_score': 5.477,
#   'economy_gdp_per_capita': 10.189,
#   'health_life_expectancy': 0.569798068,
#   'freedom': 0.718,
#   'trust_government_corruption': 0.845,
#   'generosity': -0.111,
#   'year': 2021},
#  {'country': 'Tajikistan',
#   'happiness_rank': 78,
#   'happiness_score': 5.466,
#   'economy_gdp_per_capita': 8.091,
#   'health_life_expectancy': 0.554978051,
#   'freedom': 0.832,
#   'trust_government_corruption': 0.553,
#   'generosity': -0.056,
#   'year': 2021},
#  {'country': 'Vietnam',
#   'happiness_rank': 79,
#   'happiness_score': 5.411,
#   'economy_gdp_per_capita': 8.973,
#   'health_life_expectancy': 0.686777875,
#   'freedom': 0.94,
#   'trust_government_corruption': 0.796,
#   'generosity': -0.098,
#   'year': 2021},
#  {'country': 'Libya',
#   'happiness_rank': 80,
#   'happiness_score': 5.41,
#   'economy_gdp_per_capita': 9.622,
#   'health_life_expectancy': 0.485408253,
#   'freedom': 0.771,
#   'trust_government_corruption': 0.667,
#   'generosity': -0.087,
#   'year': 2021},
#  {'country': 'Malaysia',
#   'happiness_rank': 81,
#   'happiness_score': 5.384,
#   'economy_gdp_per_capita': 10.238,
#   'health_life_expectancy': 0.65404741,
#   'freedom': 0.895,
#   'trust_government_corruption': 0.839,
#   'generosity': 0.125,
#   'year': 2021},
#  {'country': 'Indonesia',
#   'happiness_rank': 82,
#   'happiness_score': 5.345,
#   'economy_gdp_per_capita': 9.365,
#   'health_life_expectancy': 0.483160667,
#   'freedom': 0.873,
#   'trust_government_corruption': 0.867,
#   'generosity': 0.542,
#   'year': 2021},
#  {'country': 'China',
#   'happiness_rank': 84,
#   'happiness_score': 5.339,
#   'economy_gdp_per_capita': 9.673,
#   'health_life_expectancy': 0.741527656,
#   'freedom': 0.904,
#   'trust_government_corruption': 0.755,
#   'generosity': -0.146,
#   'year': 2021},
#  {'country': 'Ivory Coast',
#   'happiness_rank': 85,
#   'happiness_score': 5.306,
#   'economy_gdp_per_capita': 8.551,
#   'health_life_expectancy': 0.057453907,
#   'freedom': 0.741,
#   'trust_government_corruption': 0.794,
#   'generosity': -0.016,
#   'year': 2021},
#  {'country': 'Armenia',
#   'happiness_rank': 86,
#   'happiness_score': 5.283,
#   'economy_gdp_per_capita': 9.487,
#   'health_life_expectancy': 0.652396839,
#   'freedom': 0.825,
#   'trust_government_corruption': 0.629,
#   'generosity': -0.168,
#   'year': 2021},
#  {'country': 'Nepal',
#   'happiness_rank': 87,
#   'happiness_score': 5.269,
#   'economy_gdp_per_capita': 8.12,
#   'health_life_expectancy': 0.553292362,
#   'freedom': 0.782,
#   'trust_government_corruption': 0.727,
#   'generosity': 0.152,
#   'year': 2021},
#  {'country': 'Bulgaria',
#   'happiness_rank': 88,
#   'happiness_score': 5.266,
#   'economy_gdp_per_capita': 10.016,
#   'health_life_expectancy': 0.65046532,
#   'freedom': 0.788,
#   'trust_government_corruption': 0.932,
#   'generosity': -0.096,
#   'year': 2021},
#  {'country': 'Maldives',
#   'happiness_rank': 89,
#   'happiness_score': 5.198,
#   'economy_gdp_per_capita': 9.826,
#   'health_life_expectancy': 0.776892011,
#   'freedom': 0.854,
#   'trust_government_corruption': 0.825,
#   'generosity': 0.024,
#   'year': 2021},
#  {'country': 'Azerbaijan',
#   'happiness_rank': 90,
#   'happiness_score': 5.171,
#   'economy_gdp_per_capita': 9.569,
#   'health_life_expectancy': 0.603266023,
#   'freedom': 0.814,
#   'trust_government_corruption': 0.506,
#   'generosity': -0.223,
#   'year': 2021},
#  {'country': 'Cameroon',
#   'happiness_rank': 91,
#   'happiness_score': 5.142,
#   'economy_gdp_per_capita': 8.189,
#   'health_life_expectancy': 0.176892011,
#   'freedom': 0.731,
#   'trust_government_corruption': 0.848,
#   'generosity': 0.026,
#   'year': 2021},
#  {'country': 'Senegal',
#   'happiness_rank': 92,
#   'happiness_score': 5.132,
#   'economy_gdp_per_capita': 8.118,
#   'health_life_expectancy': 0.397682177,
#   'freedom': 0.695,
#   'trust_government_corruption': 0.801,
#   'generosity': -0.046,
#   'year': 2021},
#  {'country': 'Albania',
#   'happiness_rank': 93,
#   'happiness_score': 5.117,
#   'economy_gdp_per_capita': 9.52,
#   'health_life_expectancy': 0.720667252,
#   'freedom': 0.785,
#   'trust_government_corruption': 0.901,
#   'generosity': -0.03,
#   'year': 2021},
#  {'country': 'Ghana',
#   'happiness_rank': 95,
#   'happiness_score': 5.088,
#   'economy_gdp_per_capita': 8.58,
#   'health_life_expectancy': 0.319859526,
#   'freedom': 0.807,
#   'trust_government_corruption': 0.848,
#   'generosity': 0.123,
#   'year': 2021},
#  {'country': 'Niger',
#   'happiness_rank': 96,
#   'happiness_score': 5.074,
#   'economy_gdp_per_capita': 7.098,
#   'health_life_expectancy': 0.18619842,
#   'freedom': 0.806,
#   'trust_government_corruption': 0.693,
#   'generosity': 0.018,
#   'year': 2021},
#  {'country': 'Turkmenistan',
#   'happiness_rank': 97,
#   'happiness_score': 5.066,
#   'economy_gdp_per_capita': 9.629,
#   'health_life_expectancy': 0.489236172,
#   'freedom': 0.877,
#   'trust_government_corruption': 0.888,
#   'generosity': 0.273,
#   'year': 2021},
#  {'country': 'Benin',
#   'happiness_rank': 99,
#   'happiness_score': 5.045,
#   'economy_gdp_per_capita': 8.087,
#   'health_life_expectancy': 0.218964004,
#   'freedom': 0.757,
#   'trust_government_corruption': 0.661,
#   'generosity': -0.034,
#   'year': 2021},
#  {'country': 'Laos',
#   'happiness_rank': 100,
#   'happiness_score': 5.03,
#   'economy_gdp_per_capita': 8.947,
#   'health_life_expectancy': 0.368393327,
#   'freedom': 0.91,
#   'trust_government_corruption': 0.658,
#   'generosity': 0.123,
#   'year': 2021},
#  {'country': 'Bangladesh',
#   'happiness_rank': 101,
#   'happiness_score': 5.025,
#   'economy_gdp_per_capita': 8.454,
#   'health_life_expectancy': 0.573204565,
#   'freedom': 0.877,
#   'trust_government_corruption': 0.682,
#   'generosity': -0.041,
#   'year': 2021},
#  {'country': 'Guinea',
#   'happiness_rank': 102,
#   'happiness_score': 4.984,
#   'economy_gdp_per_capita': 7.838,
#   'health_life_expectancy': 0.229323968,
#   'freedom': 0.697,
#   'trust_government_corruption': 0.766,
#   'generosity': 0.095,
#   'year': 2021},
#  {'country': 'South Africa',
#   'happiness_rank': 103,
#   'happiness_score': 4.956,
#   'economy_gdp_per_capita': 9.403,
#   'health_life_expectancy': 0.295908692,
#   'freedom': 0.749,
#   'trust_government_corruption': 0.86,
#   'generosity': -0.067,
#   'year': 2021},
#  {'country': 'Turkey',
#   'happiness_rank': 104,
#   'happiness_score': 4.948,
#   'economy_gdp_per_capita': 10.24,
#   'health_life_expectancy': 0.657453907,
#   'freedom': 0.576,
#   'trust_government_corruption': 0.776,
#   'generosity': -0.139,
#   'year': 2021},
#  {'country': 'Pakistan',
#   'happiness_rank': 105,
#   'happiness_score': 4.934,
#   'economy_gdp_per_capita': 8.458,
#   'health_life_expectancy': 0.359297629,
#   'freedom': 0.726,
#   'trust_government_corruption': 0.787,
#   'generosity': 0.098,
#   'year': 2021},
#  {'country': 'Morocco',
#   'happiness_rank': 106,
#   'happiness_score': 4.918,
#   'economy_gdp_per_capita': 8.903,
#   'health_life_expectancy': 0.622651449,
#   'freedom': 0.774,
#   'trust_government_corruption': 0.801,
#   'generosity': -0.236,
#   'year': 2021},
#  {'country': 'Venezuela',
#   'happiness_rank': 107,
#   'happiness_score': 4.892,
#   'economy_gdp_per_capita': 9.073,
#   'health_life_expectancy': 0.639929763,
#   'freedom': 0.615,
#   'trust_government_corruption': 0.827,
#   'generosity': -0.169,
#   'year': 2021},
#  {'country': 'Algeria',
#   'happiness_rank': 109,
#   'happiness_score': 4.887,
#   'economy_gdp_per_capita': 9.342,
#   'health_life_expectancy': 0.615522388,
#   'freedom': 0.48,
#   'trust_government_corruption': 0.752,
#   'generosity': -0.067,
#   'year': 2021},
#  {'country': 'Ukraine',
#   'happiness_rank': 110,
#   'happiness_score': 4.875,
#   'economy_gdp_per_capita': 9.436,
#   'health_life_expectancy': 0.576786655,
#   'freedom': 0.724,
#   'trust_government_corruption': 0.924,
#   'generosity': -0.011,
#   'year': 2021},
#  {'country': 'Iraq',
#   'happiness_rank': 111,
#   'happiness_score': 4.854,
#   'economy_gdp_per_capita': 9.24,
#   'health_life_expectancy': 0.425109745,
#   'freedom': 0.63,
#   'trust_government_corruption': 0.875,
#   'generosity': -0.053,
#   'year': 2021},
#  {'country': 'Gabon',
#   'happiness_rank': 112,
#   'happiness_score': 4.852,
#   'economy_gdp_per_capita': 9.603,
#   'health_life_expectancy': 0.403301141,
#   'freedom': 0.731,
#   'trust_government_corruption': 0.84,
#   'generosity': -0.2,
#   'year': 2021},
#  {'country': 'Burkina Faso',
#   'happiness_rank': 113,
#   'happiness_score': 4.834,
#   'economy_gdp_per_capita': 7.678,
#   'health_life_expectancy': 0.199227392,
#   'freedom': 0.695,
#   'trust_government_corruption': 0.748,
#   'generosity': -0.009,
#   'year': 2021},
#  {'country': 'Cambodia',
#   'happiness_rank': 114,
#   'happiness_score': 4.83,
#   'economy_gdp_per_capita': 8.36,
#   'health_life_expectancy': 0.474872695,
#   'freedom': 0.959,
#   'trust_government_corruption': 0.843,
#   'generosity': 0.034,
#   'year': 2021},
#  {'country': 'Mozambique',
#   'happiness_rank': 115,
#   'happiness_score': 4.794,
#   'economy_gdp_per_capita': 7.158,
#   'health_life_expectancy': 0.218718174,
#   'freedom': 0.882,
#   'trust_government_corruption': 0.684,
#   'generosity': 0.061,
#   'year': 2021},
#  {'country': 'Nigeria',
#   'happiness_rank': 116,
#   'happiness_score': 4.759,
#   'economy_gdp_per_capita': 8.533,
#   'health_life_expectancy': 0.057032485,
#   'freedom': 0.737,
#   'trust_government_corruption': 0.878,
#   'generosity': 0.037,
#   'year': 2021},
#  {'country': 'Mali',
#   'happiness_rank': 117,
#   'happiness_score': 4.723,
#   'economy_gdp_per_capita': 7.744,
#   'health_life_expectancy': 0.122598771,
#   'freedom': 0.697,
#   'trust_government_corruption': 0.827,
#   'generosity': -0.036,
#   'year': 2021},
#  {'country': 'Iran',
#   'happiness_rank': 118,
#   'happiness_score': 4.721,
#   'economy_gdp_per_capita': 9.584,
#   'health_life_expectancy': 0.625882353,
#   'freedom': 0.608,
#   'trust_government_corruption': 0.714,
#   'generosity': 0.218,
#   'year': 2021},
#  {'country': 'Uganda',
#   'happiness_rank': 119,
#   'happiness_score': 4.636,
#   'economy_gdp_per_capita': 7.677,
#   'health_life_expectancy': 0.267708516,
#   'freedom': 0.709,
#   'trust_government_corruption': 0.855,
#   'generosity': 0.122,
#   'year': 2021},
#  {'country': 'Liberia',
#   'happiness_rank': 120,
#   'happiness_score': 4.625,
#   'economy_gdp_per_capita': 7.288,
#   'health_life_expectancy': 0.281650571,
#   'freedom': 0.735,
#   'trust_government_corruption': 0.85,
#   'generosity': 0.05,
#   'year': 2021},
#  {'country': 'Kenya',
#   'happiness_rank': 121,
#   'happiness_score': 4.607,
#   'economy_gdp_per_capita': 8.361,
#   'health_life_expectancy': 0.429359087,
#   'freedom': 0.779,
#   'trust_government_corruption': 0.825,
#   'generosity': 0.287,
#   'year': 2021},
#  {'country': 'Tunisia',
#   'happiness_rank': 122,
#   'happiness_score': 4.596,
#   'economy_gdp_per_capita': 9.266,
#   'health_life_expectancy': 0.657524144,
#   'freedom': 0.656,
#   'trust_government_corruption': 0.87,
#   'generosity': -0.201,
#   'year': 2021},
#  {'country': 'Lebanon',
#   'happiness_rank': 123,
#   'happiness_score': 4.584,
#   'economy_gdp_per_capita': 9.626,
#   'health_life_expectancy': 0.662932397,
#   'freedom': 0.525,
#   'trust_government_corruption': 0.898,
#   'generosity': -0.073,
#   'year': 2021},
#  {'country': 'Namibia',
#   'happiness_rank': 124,
#   'happiness_score': 4.574,
#   'economy_gdp_per_capita': 9.161,
#   'health_life_expectancy': 0.292221247,
#   'freedom': 0.719,
#   'trust_government_corruption': 0.847,
#   'generosity': -0.149,
#   'year': 2021},
#  {'country': 'Myanmar',
#   'happiness_rank': 126,
#   'happiness_score': 4.426,
#   'economy_gdp_per_capita': 8.541,
#   'health_life_expectancy': 0.380122915,
#   'freedom': 0.876,
#   'trust_government_corruption': 0.66,
#   'generosity': 0.509,
#   'year': 2021},
#  {'country': 'Jordan',
#   'happiness_rank': 127,
#   'happiness_score': 4.395,
#   'economy_gdp_per_capita': 9.182,
#   'health_life_expectancy': 0.65046532,
#   'freedom': 0.755,
#   'trust_government_corruption': 0.705,
#   'generosity': -0.167,
#   'year': 2021},
#  {'country': 'Chad',
#   'happiness_rank': 128,
#   'happiness_score': 4.355,
#   'economy_gdp_per_capita': 7.364,
#   'health_life_expectancy': 0.0,
#   'freedom': 0.579,
#   'trust_government_corruption': 0.807,
#   'generosity': 0.041,
#   'year': 2021},
#  {'country': 'Sri Lanka',
#   'happiness_rank': 129,
#   'happiness_score': 4.325,
#   'economy_gdp_per_capita': 9.47,
#   'health_life_expectancy': 0.660965759,
#   'freedom': 0.841,
#   'trust_government_corruption': 0.863,
#   'generosity': 0.079,
#   'year': 2021},
#  {'country': 'Swaziland',
#   'happiness_rank': 130,
#   'happiness_score': 4.308,
#   'economy_gdp_per_capita': 9.065,
#   'health_life_expectancy': 0.082704126,
#   'freedom': 0.647,
#   'trust_government_corruption': 0.708,
#   'generosity': -0.185,
#   'year': 2021},
#  {'country': 'Comoros',
#   'happiness_rank': 131,
#   'happiness_score': 4.289,
#   'economy_gdp_per_capita': 8.031,
#   'health_life_expectancy': 0.311536435,
#   'freedom': 0.548,
#   'trust_government_corruption': 0.781,
#   'generosity': 0.082,
#   'year': 2021},
#  {'country': 'Egypt',
#   'happiness_rank': 132,
#   'happiness_score': 4.283,
#   'economy_gdp_per_capita': 9.367,
#   'health_life_expectancy': 0.474802458,
#   'freedom': 0.749,
#   'trust_government_corruption': 0.795,
#   'generosity': -0.182,
#   'year': 2021},
#  {'country': 'Ethiopia',
#   'happiness_rank': 133,
#   'happiness_score': 4.275,
#   'economy_gdp_per_capita': 7.694,
#   'health_life_expectancy': 0.36951712,
#   'freedom': 0.752,
#   'trust_government_corruption': 0.761,
#   'generosity': 0.082,
#   'year': 2021},
#  {'country': 'Mauritania',
#   'happiness_rank': 134,
#   'happiness_score': 4.227,
#   'economy_gdp_per_capita': 8.542,
#   'health_life_expectancy': 0.304934153,
#   'freedom': 0.561,
#   'trust_government_corruption': 0.731,
#   'generosity': -0.106,
#   'year': 2021},
#  {'country': 'Madagascar',
#   'happiness_rank': 135,
#   'happiness_score': 4.208,
#   'economy_gdp_per_capita': 7.396,
#   'health_life_expectancy': 0.38022827,
#   'freedom': 0.552,
#   'trust_government_corruption': 0.803,
#   'generosity': -0.005,
#   'year': 2021},
#  {'country': 'Togo',
#   'happiness_rank': 136,
#   'happiness_score': 4.107,
#   'economy_gdp_per_capita': 7.362,
#   'health_life_expectancy': 0.226022827,
#   'freedom': 0.619,
#   'trust_government_corruption': 0.772,
#   'generosity': 0.032,
#   'year': 2021},
#  {'country': 'Zambia',
#   'happiness_rank': 137,
#   'happiness_score': 4.073,
#   'economy_gdp_per_capita': 8.145,
#   'health_life_expectancy': 0.257453907,
#   'freedom': 0.782,
#   'trust_government_corruption': 0.823,
#   'generosity': 0.061,
#   'year': 2021},
#  {'country': 'Sierra Leone',
#   'happiness_rank': 138,
#   'happiness_score': 3.849,
#   'economy_gdp_per_capita': 7.434,
#   'health_life_expectancy': 0.11143108,
#   'freedom': 0.717,
#   'trust_government_corruption': 0.866,
#   'generosity': 0.084,
#   'year': 2021},
#  {'country': 'India',
#   'happiness_rank': 139,
#   'happiness_score': 3.819,
#   'economy_gdp_per_capita': 8.755,
#   'health_life_expectancy': 0.426865672,
#   'freedom': 0.893,
#   'trust_government_corruption': 0.774,
#   'generosity': 0.089,
#   'year': 2021},
#  {'country': 'Burundi',
#   'happiness_rank': 140,
#   'happiness_score': 3.775,
#   'economy_gdp_per_capita': 6.635,
#   'health_life_expectancy': 0.17285338,
#   'freedom': 0.626,
#   'trust_government_corruption': 0.607,
#   'generosity': -0.024,
#   'year': 2021},
#  {'country': 'Yemen',
#   'happiness_rank': 141,
#   'happiness_score': 3.658,
#   'economy_gdp_per_capita': 7.578,
#   'health_life_expectancy': 0.30356453,
#   'freedom': 0.602,
#   'trust_government_corruption': 0.8,
#   'generosity': -0.147,
#   'year': 2021},
#  {'country': 'Tanzania',
#   'happiness_rank': 142,
#   'happiness_score': 3.623,
#   'economy_gdp_per_capita': 7.876,
#   'health_life_expectancy': 0.334363477,
#   'freedom': 0.833,
#   'trust_government_corruption': 0.577,
#   'generosity': 0.183,
#   'year': 2021},
#  {'country': 'Haiti',
#   'happiness_rank': 143,
#   'happiness_score': 3.615,
#   'economy_gdp_per_capita': 7.477,
#   'health_life_expectancy': 0.253625988,
#   'freedom': 0.593,
#   'trust_government_corruption': 0.721,
#   'generosity': 0.422,
#   'year': 2021},
#  {'country': 'Malawi',
#   'happiness_rank': 144,
#   'happiness_score': 3.6,
#   'economy_gdp_per_capita': 6.958,
#   'health_life_expectancy': 0.332572432,
#   'freedom': 0.78,
#   'trust_government_corruption': 0.729,
#   'generosity': 0.038,
#   'year': 2021},
#  {'country': 'Lesotho',
#   'happiness_rank': 145,
#   'happiness_score': 3.512,
#   'economy_gdp_per_capita': 7.926,
#   'health_life_expectancy': 0.007796313,
#   'freedom': 0.715,
#   'trust_government_corruption': 0.915,
#   'generosity': -0.131,
#   'year': 2021},
#  {'country': 'Botswana',
#   'happiness_rank': 146,
#   'happiness_score': 3.467,
#   'economy_gdp_per_capita': 9.782,
#   'health_life_expectancy': 0.378964004,
#   'freedom': 0.824,
#   'trust_government_corruption': 0.801,
#   'generosity': -0.246,
#   'year': 2021},
#  {'country': 'Rwanda',
#   'happiness_rank': 147,
#   'happiness_score': 3.415,
#   'economy_gdp_per_capita': 7.676,
#   'health_life_expectancy': 0.45380158,
#   'freedom': 0.897,
#   'trust_government_corruption': 0.167,
#   'generosity': 0.061,
#   'year': 2021},
#  {'country': 'Zimbabwe',
#   'happiness_rank': 148,
#   'happiness_score': 3.145,
#   'economy_gdp_per_capita': 7.943,
#   'health_life_expectancy': 0.271220369,
#   'freedom': 0.677,
#   'trust_government_corruption': 0.821,
#   'generosity': -0.047,
#   'year': 2021},
#  {'country': 'Afghanistan',
#   'happiness_rank': 149,
#   'happiness_score': 2.523,
#   'economy_gdp_per_capita': 7.695,
#   'health_life_expectancy': 0.141000878,
#   'freedom': 0.382,
#   'trust_government_corruption': 0.924,
#   'generosity': -0.102,
#   'year': 2021}]

# %%
world_data.to_json(orient='records')
# Out:
iness_score":7.064,"economy_gdp_per_capita":10.707,"health_life_expectancy":0.843617208,"freedom":0.859,"trust_government_corruption":0.459,"generosity":0.233,"year":2021},{"country":"Czech Republic","happiness_rank":18,"happiness_score":6.965,"economy_gdp_per_capita":10.556,"health_life_expectancy":0.784161545,"freedom":0.858,"trust_government_corruption":0.868,"generosity":-0.208,"year":2021},{"country":"United States","happiness_rank":19,"happiness_s ...

# %%
def pullData(year, x, y):
    y_data = pd.read_sql(f"SELECT {y} FROM happiness_data WHERE year = {year}")
    if x = yearly_average_temp:
        x_data = pd.read_sql(f"SELECT {x}")
#     else if y= yearly_average_temp:
#         x_data = 
    else:
    x_data = pd.read_sql(f"SELECT {x} FROM happiness_data WHERE year = {year}")
    y_data = pd.read_sql(f"SELECT happiness_score FROM happiness_data WHERE year = {year}")
# Out:
#   File "<ipython-input-5-091319064084>", line 3
#     if x = yearly_average_temp:
#          ^
# SyntaxError: invalid syntax

# %%
regression_list = []
years_list= [2021, 2020, 2019, 2018, 2017, 2016, 2015]
x_headers = ["economy_gdp_per_capita", "health_life_expectancy", "freedom", "trust_government_corruption", "generosity"]
for year in years_list:
    for x_category in x_headers:
        # Requesting the the data from the database
        scat_df = pd.read_sql(f"SELECT happiness_score, {x_category} FROM happiness_data WHERE year = {year}", con=engine)
        scat_df_json = scat_df.to_json()
        # creating the scatter plot  and regression line which I'm not sure if it's necessary
        fig = px.scatter(scat_df, x=x_category, y="happiness_score", trendline="ols")
        
        # getting slope, r and p values to print later
        (slope, intercept, rvalue, pvalue, stderr) = linregress(scat_df[x_category], scat_df["happiness_score"])
        
        # creating a line equation
        line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
        
        # adding an annotation of the slope of the line on the figure
        
        #  So here I would append each variable and graph into a dictionary or json where the next python code can access? 
        #  How would I call each dictionary a  uniqu name? or I don't need to?
        dictionary = {"year": year,
               "x_category": x_category,
               "scat_df": scat_df_json,
               "line_eq": line_eq,
               }
        
        regression_list.append(dictionary)
regression_list
# Out:
# [{'year': 2021,
#   'x_category': 'economy_gdp_per_capita',
#   'scat_df':      happiness_score  economy_gdp_per_capita
#   0              7.842                  10.775
#   1              7.620                  10.933
#   2              7.571                  11.117
#   3              7.554                  10.878
#   4              7.464                  10.932
#   ..               ...                     ...
#   135            3.512                   7.926
#   136            3.467                   9.782
#   137            3.415                   7.676
#   138            3.145                   7.943
#   139            2.523                   7.695
#
#   [140 rows x 2 columns],
#   'line_eq': 'y = 0.76x + -1.63',
#   'fig': Figure({
#       'data': [{'hovertemplate': 'economy_gdp_per_capita=%{x}<br>happiness_score=%{y}<extra></extra>',
#                 'legendgroup': '',
#                 'marker': {'color': '#636efa', 'symbol': 'circle'},
#                 'mode': 'markers',
#                 'name': '',
#                 'orientation': 'v',
#                 'showlegend': False,
#                 'type': 'scatter',
#                 'x': array([10.775, 10.933, 11.117, 10.878, 10.932, 11.053, 10.867, 11.647, 10.643,
#                             10.906, 10.796, 10.575, 10.873, 10.776, 11.342,  9.88 , 10.707, 10.556,
#                             11.023, 10.823, 10.704, 10.669, 10.674, 11.085, 10.743, 10.571, 10.623,
#                             10.529,  9.053,  9.966, 11.488, 10.369,  9.577,  9.859,  9.186, 10.499,
#                             10.576, 10.481, 10.35 ,  8.836, 10.071, 10.382, 10.155, 10.284, 10.817,
#                              9.787,  9.054, 10.008, 10.315,  9.557, 10.358,  9.805,  8.62 , 10.611,
#                             0.803, 0.806, 0.807, 0.809, 0.809, 0.812, 0.821, 0.823, 0.823, 0.825,
#                             0.825, 0.826, 0.827, 0.827, 0.83 , 0.834, 0.835, 0.839, 0.839, 0.84 ,
#                             0.841, 0.843, 0.843, 0.844, 0.845, 0.847, 0.848, 0.848, 0.85 , 0.855,
#                             0.856, 0.856, 0.86 , 0.863, 0.866, 0.866, 0.867, 0.868, 0.87 , 0.875,
#                             0.876, 0.878, 0.882, 0.884, 0.887, 0.888, 0.891, 0.895, 0.898, 0.901,
#                             0.908, 0.911, 0.915, 0.918, 0.924, 0.924, 0.931, 0.932, 0.938, 0.939]),
#                 'xaxis': 'x',
#                 'y': array([7.24366625, 7.01925512, 6.98757355, 6.96909263, 6.83444595, 6.8212453 ,
#                             6.74732163, 6.68923875, 6.56779272, 6.50178945, 6.44106644, 6.36450264,
#                             6.2932191 , 6.24833688, 6.24569675, 6.190254  , 6.12425072, 6.10048954,
#                             6.06880797, 6.00016457, 5.95264221, 5.93680142, 5.90511985, 5.90247972,
#                             5.8575975 , 5.80479488, 5.79951461, 5.77575344, 5.75463239, 5.73615147,
#                             5.72295082, 5.71767056, 5.71503042, 5.70711003, 5.69918964, 5.68334885,
#                             5.65958767, 5.65430741, 5.65430741, 5.64374689, 5.63054623, 5.61734558,
#                             5.59886466, 5.59094427, 5.57510348, 5.57510348, 5.55662257, 5.55398244,
#                             5.54078178, 5.54078178, 5.53550152, 5.53022126, 5.52494099, 5.51966073,
#                             5.5170206 , 5.50117982, 5.49325942, 5.48533903, 5.47477851, 5.47213838,
#                             5.46685811, 5.46421798, 5.45101733, 5.43781667, 5.42197589, 5.41669563,
#                             5.41405549, 5.41141536, 5.39821471, 5.38237392, 5.37709366, 5.36389301,
#                             5.36125288, 5.35861274, 5.35069235, 5.34805222, 5.34805222, 5.34541209,
#                             5.34541209, 5.34541209, 5.34013183, 5.33221143, 5.3295713 , 5.32429104,
#                             5.32429104, 5.31637065, 5.29260947, 5.28732921, 5.28732921, 5.28204895,
#                             5.28204895, 5.27940882, 5.27676868, 5.27676868, 5.26884829, 5.25828777,
#                             5.25564764, 5.24508711, 5.24508711, 5.24244698, 5.23980685, 5.23452659,
#                             5.23452659, 5.23188646, 5.22924633, 5.22396607, 5.22132593, 5.22132593,
#                             5.21604567, 5.20284502, 5.20020489, 5.20020489, 5.18964436, 5.18172397,
#                             5.17380358, 5.17380358, 5.17116345, 5.16852332, 5.16324305, 5.1500424 ,
#                             5.14740227, 5.14212201, 5.13156148, 5.12628122, 5.11836083, 5.1157207 ,
#                             5.1078003 , 5.09723978, 5.08931939, 5.08139899, 5.06291808, 5.05499768,
#                             5.04443716, 5.03651677, 5.02067598, 5.02067598, 5.00219506, 4.99955493,
#                             4.98371415, 4.98107402]),
#                 'yaxis': 'y'},
#                {'mode': 'text',
#                 'name': 'Text',
#                 'text': [Regression Equation: y = -2.64x + 7.46 r-value: -0.436],
#                 'textposition': 'bottom center',
#                 'type': 'scatter',
#                 'x': [8],
#                 'y': [7]}],
#       'layout': {'legend': {'tracegroupgap': 0},
#                  'margin': {'t': 60},
#                  'template': '...',
#                  'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'trust_government_corruption'}},
#                  'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'happiness_score'}}}
#   })},
#  {'year': 2021,
#   'x_category': 'generosity',
#   'scat_df':      happiness_score  generosity
#   0              7.842      -0.098
#   1              7.620       0.030
#   2              7.571       0.025
#   3              7.554       0.160
#   4              7.464       0.175
#   ..               ...         ...
#   135            3.512      -0.131
#   136            3.467      -0.246
#   137            3.415       0.061
#   138            3.145      -0.047
#   139            2.523      -0.102
#
#   [140 rows x 2 columns],
#   'line_eq': 'y = -0.22x + 5.54',
#   'fig': Figure({
#       'data': [{'hovertemplate': 'generosity=%{x}<br>happiness_score=%{y}<extra></extra>',
#                 'legendgroup': '',
#                 'marker': {'color': '#636efa', 'symbol': 'circle'},
#                 'mode': 'markers',
#                 'name': '',
#                 'orientation': 'v',
#                 'showlegend': False,
#                 'type': 'scatter',
#                 'x': array([-0.098,  0.03 ,  0.025,  0.16 ,  0.175,  0.093,  0.086, -0.034,  0.134,
#                              0.042,  0.159,  0.031,  0.011,  0.089,  0.077, -0.126,  0.233, -0.208,
#                              0.098, -0.153, -0.147,  0.089,  0.133,  0.074, -0.149, -0.081, -0.084,
#                             -0.101, -0.038, -0.092, -0.018, -0.124, -0.071, -0.147, -0.137, -0.203,
#                             -0.015, -0.106, -0.166,  0.311, -0.044, -0.165, -0.069, -0.219, -0.104,
#                              0.002, -0.11 , -0.054, -0.162, -0.135, -0.186,  0.287,  0.02 , -0.258,
#                             -0.182, -0.244,  0.081, -0.118, -0.097, -0.083, -0.154,  0.113, -0.079,
#                             -0.124,  0.119, -0.288, -0.077,  0.116,  0.028, -0.034, -0.133, -0.18 ,
#                             -0.111, -0.056, -0.098, -0.087,  0.125,  0.542, -0.146, -0.016, -0.168,
#                              0.152, -0.096,  0.024, -0.223,  0.026, -0.046, -0.03 ,  0.123,  0.018,
#                              0.273, -0.034,  0.123, -0.041,  0.095, -0.067, -0.139,  0.098, -0.236,
#                             -0.169, -0.067, -0.011, -0.053, -0.2  , -0.009,  0.034,  0.061,  0.037,
#                             -0.036,  0.218,  0.122,  0.05 ,  0.287, -0.201, -0.073, -0.149,  0.509,
#                             -0.167,  0.041,  0.079, -0.185,  0.082, -0.182,  0.082, -0.106, -0.005,
#                              0.032,  0.061,  0.084,  0.089, -0.024, -0.147,  0.183,  0.422,  0.038,
#                             -0.131, -0.246,  0.061, -0.047, -0.102]),
#                 'xaxis': 'x',
#                 'y': array([7.842, 7.62 , 7.571, 7.554, 7.464, 7.392, 7.363, 7.324, 7.277, 7.268,
#                             7.183, 7.157, 7.155, 7.103, 7.085, 7.069, 7.064, 6.965, 6.951, 6.834,
#                             6.69 , 6.647, 6.602, 6.561, 6.494, 6.491, 6.483, 6.461, 6.435, 6.431,
#                             6.377, 6.331, 6.33 , 6.317, 6.309, 6.255, 6.223, 6.189, 6.18 , 6.179,
#                             6.172, 6.166, 6.152, 6.14 , 6.106, 6.078, 6.061, 6.049, 6.032, 6.012,
#                             5.992, 5.985, 5.972, 5.94 , 5.929, 5.929, 5.919, 5.882, 5.88 , 5.845,
#                             5.84 , 5.813, 5.766, 5.764, 5.744, 5.723, 5.716, 5.677, 5.653, 5.581,
#                             5.545, 5.534, 5.477, 5.466, 5.411, 5.41 , 5.384, 5.345, 5.339, 5.306,
#                             5.283, 5.269, 5.266, 5.198, 5.171, 5.142, 5.132, 5.117, 5.088, 5.074,
#                             5.066, 5.045, 5.03 , 5.025, 4.984, 4.956, 4.948, 4.934, 4.918, 4.892,
#                             4.887, 4.875, 4.854, 4.852, 4.834, 4.83 , 4.794, 4.759, 4.723, 4.721,
#                             4.636, 4.625, 4.607, 4.596, 4.584, 4.574, 4.426, 4.395, 4.355, 4.325,
#                             4.308, 4.289, 4.283, 4.275, 4.227, 4.208, 4.107, 4.073, 3.849, 3.819,
#                             3.775, 3.658, 3.623, 3.615, 3.6  , 3.512, 3.467, 3.415, 3.145, 2.523]),
#                 'yaxis': 'y'},
#                {'hovertemplate': ('<b>OLS trendline</b><br>happin' ... ' <b>(trend)</b><extra></extra>'),
#                 'legendgroup': '',
#                 'marker': {'color': '#636efa', 'symbol': 'circle'},
#                 'mode': 'lines',
#                 'name': '',
#                 'showlegend': False,
#                 'type': 'scatter',
#                 'x': array
#                             5.51467456, 5.51401675, 5.51401675, 5.51072768, 5.51006986, 5.50941205,
#                             5.50875423, 5.50853496, 5.50853496, 5.50809642, 5.50634224, 5.50612297,
#                             5.50217608, 5.50064118, 5.50042191, 5.49713284, 5.49537866, 5.48770416,
#                             5.48441508, 5.47564422, 5.47257442, 5.47257442, 5.4673119 , 5.44297275,
#                             5.42389612, 5.41666016]),
#                 'yaxis': 'y'},
#                {'mode': 'text',
#                 'name': 'Text',
#                 'text': [Regression Equation: y = -0.22x + 5.54 r-value: -0.029],
#                 'textposition': 'bottom center',
#                 'type': 'scatter',
#                 'x': [8],
#                 'y': [7]}],
#       'layout': {'legend': {'tracegroupgap': 0},
#                  'margin': {'t': 60},
#                  'template': '...',
#                  'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'generosity'}},
#                  'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'happiness_score'}}}
#   })},
#  {'year': 2020,
#   'x_category': 'economy_gdp_per_capita',
#   'scat_df':      happiness_score  economy_gdp_per_capita
#   0             7.8087               10.639267
#   1             7.6456               10.774001
#   2             7.5599               10.979933
#   3             7.5045               10.772559
#   4             7.4880               11.087804
#   ..               ...                     ...
#   136           3.4762                7.967665
#   137           3.4759                6.625160
#   138           3.3123                7.600104
#   139           3.2992                7.865712
#   140           2.5669                7.462861
#
#   [141 rows x 2 columns],
#   'line_eq': 'y = 0.74x + -1.35',
#   'fig': Figure({
#       'data': [{'hovertemplate': 'economy_gdp_per_capita=%{x}<br>happiness_score=%{y}<extra></extra>',
#                 'legendgroup': '',
#                 'marker': {'color': '#636efa', 'symbol': 'circle'},
#                 'mode': 'markers',
#                 'name': '',
#                 'orientation': 'v',
#                 'showlegend': False,
#                 'type': 'scatter',
#                 'x': array([10.63926697, 10.77400112, 10.97993279, 10.77255917, 11.08780384,
#                             10.81271172, 10.75879383, 10.50094318, 10.7428236 , 11.45068073,
#                             10.69236851, 10.72059631, 10.60013485, 10.41752529,  9.6581564 ,
#                             11.16097832, 10.7328186 , 10.92576885, 10.40416336, 10.6736393 ,
#                             11.1099987 , 10.53383827, 10.58422279,  9.7977972 ,  9.9481926 ,
#                             10.79781246, 10.46292686,  8.92480564, 10.48183632, 11.39552116,
#                              9.56643486, 10.39232254,  8.90907574, 10.03423405, 10.34774971,
#                              8.7403717 , 10.0320549 , 10.67638016, 10.34362602, 10.26512432,
#                              9.50036907, 10.40570259,  8.49316025, 10.107584  , 11.08982468,
#                              9.95678616, 10.11465836, 10.34001732,  8.99354553, 10.24924374,
#                              9.74179173,  9.81095505,  8.4245348 , 10.17531967,  9.24605846,
#                             10.26374245,  9.00625038, 10.51056671, 10.57968903,  9.45631313,
#                              9.68098068,  8.85111523,  8.48272705,  9.38998222,  9.66488075,
# ...
#                             5.878, 5.855, 5.848, 5.833, 5.828, 5.824, 5.813, 5.791, 5.77 , 5.759,
#                             5.754, 5.716, 5.709, 5.689, 5.605, 5.548, 5.477, 5.429, 5.399, 5.36 ,
#                             5.332, 5.286, 5.268, 5.253, 5.212, 5.194, 5.192, 5.192, 5.14 , 5.129,
#                             5.124, 5.123, 5.102, 5.098, 5.073, 5.013, 4.971, 4.959, 4.949, 4.898,
#                             4.885, 4.876, 4.874, 4.867, 4.857, 4.839, 4.8  , 4.788, 4.786, 4.739,
#                             4.694, 4.686, 4.681, 4.677, 4.642, 4.633, 4.61 , 4.571, 4.565, 4.55 ,
#                             4.518, 4.514, 4.512, 4.507, 4.436, 4.419, 4.369, 4.35 , 4.332, 4.307,
#                             4.292, 4.271, 4.252, 4.218, 4.194, 4.077, 4.033, 3.995, 3.956, 3.931,
#                             3.904, 3.896, 3.845, 3.819, 3.781, 3.681, 3.678, 3.667, 3.656, 3.655,
#                             3.587, 3.575, 3.465, 3.34 , 3.006, 2.905, 2.839]),
#                 'yaxis': 'y'},
#                {'hovertemplate': ('<b>OLS trendline</b><br>happin' ... ' <b>(trend)</b><extra></extra>'),
#                 'legendgroup': '',
#                 'marker': {'color': '#636efa', 'symbol': 'circle'},
#                 'mode': 'lines',
#                 'name': '',
#                 'showlegend': False,
#                 'type': 'scatter',
#                 'x': array([0
#                             5.28677305, 5.302579  , 5.30867496, 5.31185357, 5.31690451, 5.31716576,
#                             5.31847204, 5.32130231, 5.33275401, 5.33436508, 5.36558511, 5.36763161,
#                             5.37438071, 5.38992541, 5.3938007 , 5.39636971, 5.39650034, 5.41234984,
#                             5.42924436, 5.43028938, 5.43516615, 5.44653076, 5.45341049, 5.45497802,
#                             5.45963708, 5.46590721, 5.47352716, 5.52185942, 5.53091627, 5.5343126 ,
#                             5.53692515, 5.55438572, 5.5603946 , 5.56170088, 5.58721683, 5.59723162,
#                             5.60280507, 5.60524345, 5.61512762, 5.64051294, 5.6729957 , 5.70199506,
#                             5.72511617, 5.75546534, 5.82987961, 5.84333426, 5.88909751, 5.99777978,
#                             6.02381825, 6.10641851, 6.11625914, 6.1170429 , 6.1592792 , 6.17029547,
#                             6.19019443, 6.19019443, 6.20904837, 6.32574247, 6.36345035, 6.41983798,
#                             6.45401891, 6.57545915, 6.60184595, 6.64295015, 6.6830964 , 6.87960405,
#                             6.91674587, 7.04728652, 7.17717402]),
#                 'yaxis': 'y'},
#                {'mode': 'text',
#                 'name': 'Text',
#                 'text': [Regression Equation: y = 4.35x + 4.77 r-value: 0.44],
#                 'textposition': 'bottom center',
#                 'type': 'scatter',
#                 'x': [8],
#                 'y': [7]}],
#       'layout': {'legend': {'tracegroupgap': 0},
#                  'margin': {'t': 60},
#                  'template': '...',
#                  'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'trust_government_corruption'}},
#                  'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'happiness_score'}}}
#   })},
#  {'year': 2015,
#   'x_category': 'generosity',
#   'scat_df':      happiness_score  generosity
#   0              7.587     0.29678
#   1              7.561     0.43630
#   2              7.527     0.34139
#   3              7.522     0.34699
#   4              7.427     0.45811
#   ..               ...         ...
#   142            3.465     0.22628
#   143            3.340     0.18260
#   144            3.006     0.47179
#   145            2.905     0.19727
#   146            2.839     0.16681
#
#   [147 rows x 2 columns],
#   'line_eq': 'y = 1.55x + 5.03',
#   'fig': Figure({
#       'data': [{'hovertemplate': 'generosity=%{x}<br>happiness_score=%{y}<extra></extra>',
#                 'legendgroup': '',
#                 'marker': {'color': '#636efa', 'symbol': 'circle'},
#                 'mode': 'markers',
#                 'name': '',
#                 'orientation': 'v',
#                 'showlegend': False,
#                 'type': 'scatter',
#                 'x': array([0.29678, 0.4363 , 0.34139, 0.34699, 0.45811, 0.23351, 0.4761 , 0.36262,
#                             0.47501, 0.43562, 0.33172, 0.25497, 0.33088, 0.14074, 0.40105, 0.14574,
#                             0.28034, 0.45901, 0.2225 , 0.26428, 0.51912, 0.21542, 0.05841, 0.31105,
#                             0.24434, 0.28214, 0.33363, 0.32573, 0.12332, 0.11451, 0.10686, 0.2324 ,
#                             0.18401, 0.5763 , 0.13706, 0.18227, 0.51752, 0.16228, 0.16991, 0.10692,
#                             0.27489, 0.22837, 0.16893, 0.10705, 0.18557, 0.11541, 0.17362, 0.22823,
#                             0.20536, 0.20951, 0.3424 , 0.11827, 0.25328, 0.02641, 0.27815, 0.14982,
#                             0.11046, 0.16759, 0.33075, 0.05444, 0.18295, 0.00199, 0.2123 , 0.30638,
#                             0.07822, 0.16979, 0.37744, 0.0868 , 0.51535, 0.1686 , 0.12253, 0.3003 ,
#                             0.27233, 0.47998, 0.07799, 0.33671, 0.11053, 0.1614 , 0.08185, 0.19591,
#                             0.13748, 0.19231, 0.13719, 0.18226, 0.24991, 0.07172, 0.22269, 0.14272,
#                             0.24808, 0.16388, 0.21684, 0.42192, 0.3323 , 0.18259, 0.     , 0.21854,
#                             0.128  , 0.23027, 0.22974, 0.06431, 0.21222, 0.38086, 0.15275, 0.17922,
#                             0.11973, 0.23087, 0.18987, 0.24362, 0.26475, 0.19062, 0.46187, 0.32296,
#                             0.24325, 0.21488, 0.219  , 0.37542, 0.18093, 0.07855, 0.10461, 0.79588,
#                             0.33128, 0.40828, 0.20618, 0.11921, 0.11291, 0.09131, 0.12344, 0.18798,
#                             0.17441, 0.29066, 0.20843, 0.06822, 0.19387, 0.40359, 0.34377, 0.21333,
#                             0.23835, 0.18386, 0.28657, 0.20165, 0.21747, 0.3651 , 0.22628, 0.1826 ,
#                             0.47179, 0.19727, 0.16681]),
#                 'xaxis': 'x',
#                 'y': array([7.587, 7.561, 7.527, 7.522, 7.427, 7.406, 7.378, 7.364, 7.286, 7.284,
#                             7.278, 7.226, 7.2  , 7.187, 7.119, 6.983, 6.946, 6.94 , 6.937, 6.901,
#                             6.867, 6.853, 6.81 , 6.798, 6.786, 6.75 , 6.67 , 6.611, 6.575, 6.574,
#                             6.505, 6.485, 6.477, 6.455, 6.411, 6.329, 6.302, 6.295, 6.269, 6.13 ,
#                             6.123, 6.003, 5.995, 5.987, 5.984, 5.975, 5.96 , 5.948, 5.89 , 5.889,
#                             5.878, 5.855, 5.848, 5.833, 5.828, 5.824, 5.813, 5.791, 5.77 , 5.759,
#                             5.754, 5.716, 5.709, 5.689, 5.605, 5.548, 5.477, 5.429, 5.399, 5.36 ,
#                             5.332, 5.286, 5.268, 5.253, 5.212, 5.194, 5.192, 5.192, 5.14 , 5.129,
#                             5.124, 5.123, 5.102, 5.098, 5.073, 5.013, 4.971, 4.959, 4.949, 4.898,
#                             4.885, 4.876, 4.874, 4.867, 4.857, 4.839, 4.8  , 4.788, 4.786, 4.739,
#                             4.694, 4.686, 4.681, 4.677, 4.642, 4.633, 4.61 , 4.571, 4.565, 4.55 ,
#                             4.518, 4.514, 4.512, 4.507, 4.436, 4.419, 4.369, 4.35 , 4.332, 4.307,
#                             4.292, 4.271, 4.252, 4.218, 4.194, 4.077, 4.033, 3.995, 3.956, 3.931,
#                             3.904, 3.896, 3.845, 3.819, 3.781, 3.681, 3.678, 3.667, 3.656, 3.655,
#                             3.587, 3.575, 3.465, 3.34 , 3.006, 2.905, 2.839]),
#                 'yaxis': 'y'},
#                {'hovertemplate': ('<b>OLS trendline</b><br>happin' ... ' <b>(trend)</b><extra></extra>'),
#                 'legendgroup': '',
#                 'marker': {'color': '#636efa', 'symbol': 'circle'},
#                 'mode': 'lines',
#                 'name': '',
#                 'showlegend': False,
#                 'type': 'scatter',
#                 'x': array([0.     , 0.00199, 0.02641, 0.05444, 0.05841, 0.06431, 0.06822, 0.07172,
#                             0.07799, 0.07822, 0.07855, 0.08185, 0.0868 , 0.09131, 0.10461, 0.10686,
#                             0.10692, 0.10705, 0.11046, 0.11053, 0.11291, 0.11451, 0.11541, 0.11827,
#                             0.11921, 0.11973, 0.12253, 0.12332, 0.12344, 0.128  , 0.13706, 0.13719,
#                             0.13748, 0.14074, 0.14272, 0.14574, 0.14982, 0.15275, 0.1614 , 0.16228,
#                             5.53853281, 5.53915338, 5.53983601, 5.54073584, 5.54279925, 5.54757766,
#                             5.55483836, 5.55640531, 5.55853077, 5.56352638, 5.58777526, 5.59162281,
#                             5.60763358, 5.61076747, 5.61607337, 5.64739678, 5.65133741, 5.65861363,
#                             5.67977516, 5.70102977, 5.70208475, 5.73592147, 5.73731776, 5.74175486,
#                             5.75714506, 5.76214067, 5.76383173, 5.76985129, 5.82472543, 5.82809203,
#                             5.83057432, 5.91928519, 6.25994858]),
#                 'yaxis': 'y'},
#                {'mode': 'text',
#                 'name': 'Text',
#                 'text': [Regression Equation: y = 1.55x + 5.03 r-value: 0.168],
#                 'textposition': 'bottom center',
#                 'type': 'scatter',
#                 'x': [8],
#                 'y': [7]}],
#       'layout': {'legend': {'tracegroupgap': 0},
#                  'margin': {'t': 60},
#                  'template': '...',
#                  'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'generosity'}},
#                  'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'happiness_score'}}}
#   })}]

# %%
x_header = "economy_gdp_per_capita"
year = 2021
scat_df = pd.read_sql(f"SELECT happiness_score, {x_header} FROM happiness_data WHERE year = {year}", con=engine)

fig = px.scatter(scat_df, x=x_header, y="happiness_score", trendline="ols")
(slope, intercept, rvalue, pvalue, stderr) = linregress(scat_df[x_header], scat_df["happiness_score"])

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
fig.add_trace(go.Scatter(
    x=[8],
    y=[7],
    mode="text",
    name="Text",
    text=[f"Regression Equation: {line_eq} r-value: {round(rvalue, 3)}"],
    textposition="bottom center"
))
fig.show()
# Out:
# <div>                            <div id="076ef7fa-f58d-4215-8915-8b9336d0d4fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("076ef7fa-f58d-4215-8915-8b9336d0d4fc")) {                    Plotly.newPlot(                        "076ef7fa-f58d-4215-8915-8b9336d0d4fc",                        [{"hovertemplate": "economy_gdp_per_capita=%{x}<br>happiness_score=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [10.775, 10.933, 11.117, 10.878, 10.932, 11.052999999999999, 10.867, 11.647, 10.642999999999999, 10.905999999999999, 10.796, 10.575, 10.873, 10.776, 11.342, 9.88, 10.707, 10.556, 11.023, 10.823, 10.704, 10.669, 10.674000000000001, 11.085, 10.743, 10.571, 10.623, 10.529000000000002, 9.052999999999999, 9.966000000000001, 11.488, 10.369000000000002, 9.577, 9.859, 9.186, 10.499, 10.575999999999999, 10.481, 10.35, 8.836, 10.071, 10.382, 10.155, 10.284, 10.817, 9.787, 9.054, 10.008, 10.315, 9.557, 10.357999999999999, 9.805, 8.62, 10.610999999999999, 9.962, 10.421, 8.648, 10.217, 9.076, 10.651, 9.458, 9.59, 9.454, 9.312999999999999, 8.538, 10.279000000000002, 9.046, 9.4, 9.448, 9.94, 9.802, 9.853, 10.189, 8.091000000000001, 8.972999999999999, 9.622, 10.238, 9.365, 9.673, 8.551, 9.487, 8.12, 10.016, 9.826, 9.568999999999999, 8.189, 8.118, 9.52, 8.58, 7.098, 9.629, 8.087, 8.947000000000001, 8.454, 7.837999999999999, 9.402999999999999, 10.24, 8.458, 8.902999999999999, 9.073, 9.342, 9.436, 9.24, 9.603, 7.678, 8.36, 7.1579999999999995, 8.533, 7.744, 9.584, 7.6770000000000005, 7.287999999999999, 8.361, 9.266, 9.626, 9.161, 8.541, 9.182, 7.364, 9.47, 9.065, 8.031, 9.367, 7.694, 8.542, 7.396, 7.362, 8.145, 7.434, 8.755, 6.635, 7.577999999999999, 7.876, 7.477, 6.957999999999999, 7.926, 9.782, 7.676, 7.943, 7.695], "xaxis": "x", "y": [7.8420000000000005, 7.62, 7.571000000000001, 7.553999999999999, 7.4639999999999995, 7.392, 7.3629999999999995, 7.324, 7.277, 7.268, 7.183, 7.157, 7.155, 7.103, 7.085, 7.069, 7.064, 6.965, 6.9510000000000005, 6.834, 6.69, 6.647, 6.602, 6.561, 6.494, 6.4910000000000005, 6.483, 6.461, 6.435, 6.431, 6.377000000000001, 6.331, 6.33, 6.317, 6.309, 6.255, 6.223, 6.189, 6.18, 6.178999999999999, 6.172000000000001, 6.166, 6.152, 6.14, 6.106, 6.077999999999999, 6.061, 6.0489999999999995, 6.032, 6.0120000000000005, 5.992000000000001, 5.985, 5.972, 5.94, 5.928999999999999, 5.928999999999999, 5.919, 5.882000000000001, 5.88, 5.845, 5.84, 5.813, 5.766, 5.763999999999999, 5.744, 5.723, 5.716, 5.6770000000000005, 5.653, 5.581, 5.545, 5.534, 5.477, 5.466, 5.4110000000000005, 5.41, 5.3839999999999995, 5.345, 5.3389999999999995, 5.306, 5.2829999999999995, 5.269, 5.266, 5.1979999999999995, 5.171, 5.142, 5.132000000000001, 5.117, 5.088, 5.074, 5.066, 5.045, 5.03, 5.025, 4.984, 4.956, 4.948, 4.934, 4.918, 4.8919999999999995, 4.887, 4.875, 4.854, 4.852, 4.834, 4.83, 4.794, 4.7589999999999995, 4.723, 4.721, 4.636, 4.625, 4.607, 4.596, 4.584, 4.574, 4.426, 4.395, 4.355, 4.325, 4.308, 4.289, 4.283, 4.275, 4.227, 4.208, 4.107, 4.073, 3.8489999999999998, 3.819, 3.775, 3.658, 3.623, 3.615, 3.6, 3.512, 3.467, 3.415, 3.145, 2.523], "yaxis": "y"}, {"hovertemplate": "<b>OLS trendline</b><br>happiness_score = 0.760542 * economy_gdp_per_capita + -1.63175<br>R<sup>2</sup>=0.647977<br><br>economy_gdp_per_capita=%{x}<br>happiness_score=%{y} <b>(trend)</b><extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": [6.635, 6.957999999999999, 7.098, 7.1579999999999995, 7.287999999999999, 7.362, 7.364, 7.396, 7.434, 7.477, 7.577999999999999, 7.676, 7.6770000000000005, 7.678, 7.694, 7.6 ...

# %%
regression_dict = {}
col_dictionary = {}
year = 2021
x_headers = ["economy_gdp_per_capita", "health_life_expectancy", "freedom", "trust_government_corruption", "generosity"]
for x_category in x_headers:
    
        # Requesting the the data from the database
    scat_df = pd.read_sql(f"SELECT country, happiness_score, {x_category} FROM happiness_data WHERE year = {year}", con=engine)
    scat_df_json = scat_df.to_json()
        # creating the scatter plot  and regression line which I'm not sure if it's necessary
#         fig = px.scatter(scat_df, x=x_category, y="happiness_score", trendline="ols")
        
        # getting slope, r and p values to print later
    (slope, intercept, rvalue, pvalue, stderr) = linregress(scat_df[x_category], scat_df["happiness_score"])
        
        # creating a line equation
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    y_data = scat_df["happiness_score"].to_json(orient="records")
    x_data = scat_df[x_category].to_json(orient="records")
        # adding an annotation of the slope of the line on the figure
        
        #  So here I would append each variable and graph into a dictionary or json where the next python code can access? 
        #  How would I call each dictionary a  uniqu name? or I don't need to?
    col_dictionary[x_category] = {
            "x_category": x_category,
            "x_data": x_data,
            "y_category": "happiness_score",
            "y_data": y_data,
            "line_eq": line_eq,
            }
        
regression_dict[2021] = col_dictionary
regression_dict
json.dumps(regression_dict)
# Out:
# '{"2021": {"economy_gdp_per_capita": {"x_category": "economy_gdp_per_capita", "x_data": "[10.775,10.933,11.117,10.878,10.932,11.053,10.867,11.647,10.643,10.906,10.796,10.575,10.873,10.776,11.342,9.88,10.707,10.556,11.023,10.823,10.704,10.669,10.674,10.871,11.085,10.743,10.571,10.623,10.529,9.053,9.966,11.488,9.318,10.369,9.577,9.859,9.186,10.499,10.576,10.481,10.35,8.836,10.071,10.382,10.155,10.284,10.817,9.787,9.054,10.008,10.315,9.557,10.358,9.805,8.62,10.611,9.962,10.421,8.648,10.217,9.076,10.651,9.458,9.59,9.454,9.313,8.538,10.279,9.046,9.4,9.448,9.94,9.802,10.576,9.853,10.189,11.0,8.091,8.973,9.622,10.238,9.365,8.117,9.673,8.551,9.487,8.12,10.016,9.826,9.569,8.189,8.118,9.52,8.58,7.098,9.629,7.686,8.087,8.947,8.454,7.838,9.403,10.24,8.458,8.903,9.073,9.585,9.342,9.436,9.24,9.603,7.678,8.36,7.158,8.533,7.744,9.584,7.677,7.288,8.361,9.266,9.626,9.161,8.485,8.541,9.182,7.364,9.47,9.065,8.031,9.367,7.694,8.542,7.396,7.362,8.145,7.434,8.755,6.635,7.578,7.876,7.477,6.958,7.926,9.782,7.676,7.943,7.695,9.693]", "y_category": "happiness_score", "y_data": "[7.842,7.62,7.571,7.554,7.464,7.392,7.363,7.324,7.277,7.268,7.183,7.157,7.155,7.103,7.085,7.069,7.064,6.965,6.951,6.834,6.69,6.647,6.602,6.584,6.561,6.494,6.491,6.483,6.461,6.435,6.431,6.377,6.372,6.331,6.33,6.317,6.309,6.255,6.223,6.189,6.18,6.179,6.172,6.166,6.152,6.14,6.106,6.078,6.061,6.049,6.032,6.012,5.992,5.985,5.972,5.94,5.929,5.929,5.919,5.882,5.88,5.845,5.84,5.813,5.766,5.764,5.744,5.723,5.716,5.677,5.653,5.581,5.545,5.536,5.534,5.477,5.477,5.466,5.411,5.41,5.384,5.345,5.342,5.339,5.306,5.283,5.269,5.266,5.198,5.171,5.142,5.132,5.117,5.088,5.074,5.066,5.051,5.045,5.03,5.025,4.984,4.956,4.948,4.934,4.918,4.892,4.891,4.887,4.875,4.854,4.852,4.834,4.83,4.794,4.759,4.723,4.721,4.636,4.625,4.607,4.596,4.584,4.574,4.517,4.426,4.395,4.355,4.325,4.308,4.289,4.283,4.275,4.227,4.208,4.107,4.073,3.849,3.819,3.775,3.658,3.623,3.615,3.6,3.512,3.467,3.415,3.145,2.523,5.101]", "line_eq": "y = 0.73x + -1.37"}, "health_life_expectancy": {"x_category": "health_life_expectancy", "x_data": "[0.8260579456,0.8506409131,0.9103424056,0.8611764706,0.8401053556,0.8717120281,0.8506409131,0.8471290606,0.8752238806,0.8717120281,0.8927831431,0.8788410887,0.8436172081,0.8892712906,0.8401053556,0.8049868306,0.8436172081,0.7841615452,0.6926075505,0.833046532,0.8962949956,0.7380860404,0.8330816506,0.
.4892361721,0.2346619842,0.2189640035,0.3683933275,0.5732045654,0.2293239684,0.2959086918,0.6574539069,0.3592976295,0.6226514486,0.6399297629,0.5556453029,0.6155223881,0.576786655,0.4251097454,0.4033011414,0.1992273924,0.4748726953,0.2187181738,0.0570324846,0.1225987709,0.6258823529,0.2677085162,0.2816505707,0.4293590869,0.657524144,0.6629323968,0.2922212467,0.4836523266,0.3801229148,0.6504653205,0.0,0.6609657594,0.0827041264,0.3115364355,0.4748024583,0.3695171203,0.3049341528,0.3802282704,0.226022827,0.2574539069,0.1114310799,0.4268656716,0.1728533802,0.3035645303,0.3343634767,0.2536259877,0.332572432,0.0077963126,0.3789640035,0.4538015803,0.2712203687,0.141000878,0.5968744513]", "y_category": "happiness_score", " ...

# %%
country = "Switzerland"
line_df = pd.read_sql(f"SELECT happiness_score, year FROM happiness_data WHERE country = {country}", con=engine)
fig = px.line(line_df, x="year", y="happiness_score")
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1283                     self.dialect.do_execute(
# -> 1284                         cursor, statement, parameters, context
#    1285                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#
# UndefinedColumn: column "switzerland" does not exist
# LINE 1: ...s_score, year FROM happiness_data WHERE country = Switzerlan...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-5-2ee88d388421> in <module>
#       1 country = "Switzerland"
# ----> 2 line_df = pd.read_sql(f"SELECT happiness_score, year FROM happiness_data WHERE country = {country}", con=engine)
#       3 fig = px.line(line_df, x="year", y="happiness_score")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     436             coerce_float=coerce_float,
#     437             parse_dates=parse_dates,
# --> 438             chunksize=chunksize,
#     439         )
#     440
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2242
#    2243         connection = self._contextual_connect(close_with_result=True)
# -> 2244         return connection.execute(statement, *multiparams, **params)
#    2245
#    2246     def scalar(self, statement, *multiparams, **params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1010         """
#    1011         if isinstance(object_, util.string_types[0]):
# -> 1012             return self._execute_text(object_, multiparams, params)
#    1013         try:
#    1014             meth = object_._execute_on_connection
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1185             parameters,
#    1186             statement,
# -> 1187             parameters,
#    1188         )
#    1189         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1322         except BaseException as e:
#    1323             self._handle_dbapi_exception(
# -> 1324                 e, statement, parameters, cursor, context
#    1325             )
#    1326
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1516             elif should_wrap:
#    1517                 util.raise_(
# -> 1518                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1519                 )
#    1520             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1282                 if not evt_handled:
#    1283                     self.dialect.do_execute(
# -> 1284                         cursor, statement, parameters, context
#    1285                     )
#    1286
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     588
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#     592     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "switzerland" does not exist
# LINE 1: ...s_score, year FROM happiness_data WHERE country = Switzerlan...
#                                                              ^
#
# [SQL: SELECT happiness_score, year FROM happiness_data WHERE country = Switzerland]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
country_name = "Iceland"
time_df = pd.read_sql(f"SELECT happiness_score, year FROM happiness_data WHERE country = {country_name}", con=engine)
time_df.head()
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1283                     self.dialect.do_execute(
# -> 1284                         cursor, statement, parameters, context
#    1285                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#
# UndefinedColumn: column "iceland" does not exist
# LINE 1: ...ess_score, year FROM happiness_data WHERE country  = Iceland
#                                                                 ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-29-2a8dfbeacc6e> in <module>
#       1 country_name = "Iceland"
# ----> 2 time_df = pd.read_sql(f"SELECT happiness_score, year FROM happiness_data WHERE country  = {country_name}", con=engine)
#       3 time_df.head()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     436             coerce_float=coerce_float,
#     437             parse_dates=parse_dates,
# --> 438             chunksize=chunksize,
#     439         )
#     440
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2242
#    2243         connection = self._contextual_connect(close_with_result=True)
# -> 2244         return connection.execute(statement, *multiparams, **params)
#    2245
#    2246     def scalar(self, statement, *multiparams, **params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1010         """
#    1011         if isinstance(object_, util.string_types[0]):
# -> 1012             return self._execute_text(object_, multiparams, params)
#    1013         try:
#    1014             meth = object_._execute_on_connection
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1185             parameters,
#    1186             statement,
# -> 1187             parameters,
#    1188         )
#    1189         if self._has_events or self.engine._has_events:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1322         except BaseException as e:
#    1323             self._handle_dbapi_exception(
# -> 1324                 e, statement, parameters, cursor, context
#    1325             )
#    1326
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1516             elif should_wrap:
#    1517                 util.raise_(
# -> 1518                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1519                 )
#    1520             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1282                 if not evt_handled:
#    1283                     self.dialect.do_execute(
# -> 1284                         cursor, statement, parameters, context
#    1285                     )
#    1286
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     588
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#     592     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "iceland" does not exist
# LINE 1: ...ess_score, year FROM happiness_data WHERE country  = Iceland
#                                                                 ^
#
# [SQL: SELECT happiness_score, year FROM happiness_data WHERE country  = Iceland]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
time_df = pd.read_sql(f"SELECT country, happiness_score, year FROM happiness_data", con=engine)

# %%
time_df
# Out:
#           country  happiness_score  year
# 0     Switzerland            7.587  2015
# 1         Iceland            7.561  2015
# 2         Denmark            7.527  2015
# 3          Norway            7.522  2015
# 4          Canada            7.427  2015
# ...           ...              ...   ...
# 1077     Zimbabwe            3.145  2021
# 1078  Afghanistan            2.523  2021
# 1079      Somalia            5.057  2015
# 1080    Macedonia            5.274  2019
# 1081    Macedonia            5.101  2021
#
# [1082 rows x 3 columns]

# %%
iceland_df = time_df[time_df["country"] == "Iceland"]["year"]
iceland_df
# Out:
# 1      2015
# 159    2016
# 315    2017
# 471    2018
# 626    2019
# 781    2020
# 934    2021
# Name: year, dtype: int64

# %%
y_data = time_df[time_df["country"] == "Iceland"]["happiness_score"]
y_data
# Out:
# 1      7.5610
# 159    7.5010
# 315    7.5040
# 471    7.4950
# 626    7.4940
# 781    7.5045
# 934    7.5540
# Name: happiness_score, dtype: float64
